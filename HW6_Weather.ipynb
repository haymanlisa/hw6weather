# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %%
 # OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# response = requests.get(url +"&q="+"Paris").json()

# long = response["coord"]["lon"]
# lat = response["coord"]["lat"]
# max_temp = response["main"]["temp_max"]
# humidity = response["main"]["humidity"]
# wind_speed = response["wind"]["speed"]
# cloudiness = response["clouds"]["all"]
# country = response["sys"]["country"]
# city = response["name"]

# Weather_df= pd.DataFrame({
#     "Longtitude": [long], 
#     "Latitude": [lat], 
#     "Max Temp": [max_temp],
#     "Humidity": [humidity],
#     "Wind Speed": [wind_speed],
#     "Coudiness": [cloudiness],
#     "Country": [country],
#     "City": [city]})

long_cities = []
lat_cities = []
max_temp_cities = []
humidity_cities = []
wind_speed_cities = []
cloudiness_cities = []
country_cities = []
city_cities = []

count = 0

#to check the link to see if it works - try needs to be in the loop and what inside the try dneeds to be indented. 

# this will count the city 
for city in cities:
    count = count + 1
    print(str(count) + " " + city)
    
    print(f"{url}&q={city}|{city}")
    time.sleep(0.5)
    
    
    try:
        response = requests.get(url +"&q="+ city).json()
        long = response["coord"]["lon"]
        long_cities.append(long)

        lat = response["coord"]["lat"]
        lat_cities.append(lat)

        max_temp = response["main"]["temp_max"]
        max_temp_cities.append(max_temp)

        humidity = response["main"]["humidity"]
        humidity_cities.append(humidity)

        wind_speed = response["wind"]["speed"]
        wind_speed_cities.append(wind_speed)

        cloudiness = response["clouds"]["all"]
        cloudiness_cities.append(cloudiness)

        country = response["sys"]["country"]
        country_cities.append(country)

        city = response["name"]
        city_cities.append(city)
    except:
        print('city not found')
        pass

#will print "finish" after the links are uploaded
print("finish")
# Out:
# 1 cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b309189d61a52cb782c5539e4bd72438&q=cape town|cape town
# 2 codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b309189d61a52cb782c5539e4bd72438&q=codrington|codrington
# 3 tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b309189d61a52cb782c5539e4bd72438&q=tuktoyaktuk|tuktoyaktuk
# 4 port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b309189d61a52cb782c5539e4bd72438&q=port blair|port blair
# 5 aksum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b309189d61a52cb782c5539e4bd72438&q=aksum|aksum
# 6 puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b309189d61a52cb782c5539e4bd72438&q=puerto ayora|puerto ayora
# 7 saint-michel-des-saints
# ...

# %%
Weather_df= pd.DataFrame({
    "Longtitude": long_cities, 
    "Latitude": lat_cities, 
    "Max Temp": max_temp_cities,
    "Humidity": humidity_cities,
    "Wind Speed": wind_speed_cities,
    "Cloudiness": cloudiness_cities,
    "Country":country_cities,
    "City": city_cities})

Weather_df
# Out:
#      Longtitude  Latitude  Max Temp  Humidity  Wind Speed  Cloudiness Country  \
# 0         18.42    -33.93     66.20        68        6.93          40      ZA
# 1        153.24    -28.95     66.20        93        3.58          40      AU
# 2       -133.03     69.44    -14.81        75       10.29          75      CA
# 3         92.75     11.67     83.14        98       11.63          80      IN
# 4         38.72     14.12     41.11        41        2.35           0      ET
# 5        -90.35     -0.74     86.00        55       17.22          40      EC
# 6        -73.92     46.68      3.94        61        5.93          44      CA
# 7       -139.03     -9.80     78.73       100       16.44          80      PF
# 8        112.38     24.79     47.32        98        2.57          92      CN
# 9        167.69    -46.13     55.24       100        8.95          92      NZ
# 10        -6.59     62.23     42.80       100        1.12          92      FO
# ...

# %%
Weather_df.to_csv('out.csv')

# %%
# Temperature (F) vs. Latitude

x = Weather_df['Latitude']
y = Weather_df['Max Temp']

plt.title("Temp vs. Latitude")

plt.xlabel("Latitude")

plt.ylabel("Maximum Temperature")

plt.scatter(x, y, marker="o", facecolors="red", edgecolors="blue", s=1, alpha=1)

# %%
# Humidity (%) vs. Latitude

x = Weather_df['Latitude']
y = Weather_df['Humidity']

plt.title("Humidity vs. Latitude")

plt.xlabel("Latitude")

plt.ylabel("Humidity")

plt.scatter(x, y, marker="o", facecolors="red", edgecolors="orange", s=1, alpha=1)

# %%
# Cloudiness (%) vs. Latitude

x = Weather_df['Latitude']
y = Weather_df['Cloudiness']

plt.title("Cloudiness vs. Latitude")

plt.xlabel("Latitude")

plt.ylabel("Cloudiness")

plt.scatter(x, y, marker="o", facecolors="red", edgecolors="green", s=1, alpha=1)

# %%
# Wind Speed (mph) vs. Latitude

x = Weather_df['Latitude']
y = Weather_df['Wind Speed']

plt.title("Wind Speed vs. Latitude")

plt.xlabel("Latitude")

plt.ylabel("Wind Speed")

plt.scatter(x, y, marker="o", facecolors="red", edgecolors="brown", s=1, alpha=1)

# %% [markdown]
# Description of three observable trends based on the data
#
# Facts: 1) Positive latitude is above the equator and negative latitude is below the equator. 2)Temperatures are typically warmer approaching the Equator and cooler approaching the Poles.
#
# Observing all 4 plots, it shows that humidity and and cloudiness are spread about the same whether it is located above or below the equator. Not significant amount, but more weather changes are happening above the equator.
